# %% [markdown]
# <a href="https://colab.research.google.com/github/shorya-ag/MiniProject4_MarksAdding/blob/main/Marks_Adding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-26314a58-b492-439c-a6bc-e494ea881af3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26314a58-b492-439c-a6bc-e494ea881af3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/Mini Project - Marks Adding.csv')
df
# Out:
#        Roll Num  Marks
# 0     102003542      1
# 1     102003640      1
# 2     102003725      1
# 3     102003307      1
# 4     102003458      1
# ...         ...    ...
# 1831  102003755      1
# 1832  102017147      1
# 1833  102017152      1
# 1834  102003451      1
# 1835  102003549      1
#
# [1836 rows x 2 columns]

# %%
df['Roll Num'].value_counts()
# Out:
# 102003542    5
# 102016044    5
# 102017171    5
# 102003767    5
# 102003125    5
#             ..
# 102003396    1
# 102003690    1
# 102003582    1
# 102003089    1
# 102180347    1
# Name: Roll Num, Length: 400, dtype: int64

# %%
total_marks = df.groupby('Roll Num')['Marks'].sum()
total_marks.to_csv('output.csv')
files.download('output.csv')
